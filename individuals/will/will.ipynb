# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
import string
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/willcline/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
path = "../../data/News_Category_Dataset_v2.json"

# %%
df = pd.read_json(path,lines=True)

# %%
df.head(2)
# Out:
#         category                                           headline  \
# 0          CRIME  There Were 2 Mass Shootings In Texas Last Week...
# 1  ENTERTAINMENT  Will Smith Joins Diplo And Nicky Jam For The 2...
#
#            authors                                               link  \
# 0  Melissa Jeltsen  https://www.huffingtonpost.com/entry/texas-ama...
# 1    Andy McDonald  https://www.huffingtonpost.com/entry/will-smit...
#
#                                    short_description       date
# 0  She left her husband. He killed their children... 2018-05-26
# 1                           Of course it has a song. 2018-05-26

# %%
df['all_words'] = df['headline'] + "; " + df['short_description']

# %%
df['category'] = df['category'].replace(['CULTURE & ARTS'],'ARTS & CULTURE')

# %%
df.shape
# Out:
# (200853, 6)

# %%
df.drop(['link', 'date'], axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-104-7503e8dc7228> in <module>
# ----> 1 df.drop(['link', 'date'], axis=1, inplace=True)
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.9/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4899                 weight  1.0     0.8
#    4900         """
# -> 4901         return super().drop(
#    4902             labels=labels,
#    4903             axis=axis,
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.9/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4145         for axis, labels in axes.items():
#    4146             if labels is not None:
# -> 4147                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4148
#    4149         if inplace:
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.9/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    4180                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4181             else:
# -> 4182                 new_axis = axis.drop(labels, errors=errors)
#    4183             result = self.reindex(**{axis_name: new_axis})
#    4184
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.9/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    6016         if mask.any():
#    6017             if errors != "ignore":
# -> 6018                 raise KeyError(f"{labels[mask]} not found in axis")
#    6019             indexer = indexer[~mask]
#    6020         return self.delete(indexer)
#
# KeyError: "['link' 'date'] not found in axis"

# %%
df.head(2)

# %%
value_counts = round(df.category.value_counts(normalize=True)*100,2)

# %%
value_counts

# %% [markdown]
# ## By categories

# %%
#gets cat df, X, and y
def get_cat(cat, df):
    cat_df = df[df['category']==cat]
    cat_X = df.drop('category', axis=1)
    cat_y = df.category
    return cat_df, cat_X, cat_y

# %%
crime_df, crime_X, crime_y = get_cat('CRIME', df)

# %%
def cat_eda(df):
    category_list = df['category'].value_counts().index.tolist()
    print(category_list)
    for category in category_list:
        cat_df, cat_X, cat_y = get_cat(category, df)
        print(cat_df)

# %%
cat_eda(df)
# Out:
# ['POLITICS', 'WELLNESS', 'ENTERTAINMENT', 'TRAVEL', 'STYLE & BEAUTY', 'PARENTING', 'HEALTHY LIVING', 'QUEER VOICES', 'FOOD & DRINK', 'BUSINESS', 'COMEDY', 'SPORTS', 'BLACK VOICES', 'HOME & LIVING', 'PARENTS', 'THE WORLDPOST', 'WEDDINGS', 'WOMEN', 'IMPACT', 'DIVORCE', 'CRIME', 'MEDIA', 'WEIRD NEWS', 'GREEN', 'WORLDPOST', 'RELIGION', 'ARTS & CULTURE', 'STYLE', 'SCIENCE', 'WORLD NEWS', 'TASTE', 'TECH', 'MONEY', 'ARTS', 'FIFTY', 'GOOD NEWS', 'ENVIRONMENT', 'COLLEGE', 'LATINO VOICES', 'EDUCATION']
#         category                                           headline  \
# 13      POLITICS  Trump's Crackdown On Immigrant Parents Puts Mo...
# 14      POLITICS  'Trump's Son Should Be Concerned': FBI Obtaine...
# 15      POLITICS  Edward Snowden: There's No One Trump Loves Mor...
# 16      POLITICS  Booyah: Obama Photographer Hilariously Trolls ...
# 17      POLITICS  Ireland Votes To Repeal Abortion Amendment In ...
# ...          ...                                                ...
# 124970  POLITICS         Why Chris Christie Should NOT Be President
# 124978  POLITICS  GOP's Old Ploy: Tag President Obama as the Rac...
# 124979  POLITICS  Lawmakers Introduce Bill To Tackle Misleadingl...
# 124980  POLITICS                               Dear President Obama
# 124983  POLITICS                                   The Obama Effect
#
#                                                   authors  \
# 13                           Elise Foley and Roque Planas
# 14                            Michael Isikoff, Yahoo News
# 15                                         Mary Papenfuss
# 16                                         Mary Papenfuss
# 17                                          Laura Bassett
# ...                                                   ...
# 124970    Al Eisele, ContributorEditor-at-Large, The Hill
# 124978  Earl Ofari Hutchinson, ContributorAuthor and p...
# 124979                                     Shadee Ashtari
# 124980  Robin Amos Kahn, ContributorWriter, Speaker, L...
# 124983
#
#                                         short_description  \
# 13      Last month a Health and Human Services officia...
# 14      The wiretaps feature conversations between Ale...
# 15      But don't count on Robert Mueller to nail him,...
# 16                                 Just a peeping minute.
# 17      Irish women will no longer have to travel to t...
# ...                                                   ...
# 124970  Apparently that's just the way they play polit...
# 124978  The baiting and the assault on Obama will get ...
# 124979
# 124980  I'm assuming you are aware of this issue, Pres...
# 124983
#
#                                                lower_desc  \
# 13      trumps crackdown immigrant parents puts kids a...
# 14      trumps son concerned fbi obtained wiretaps put...
# 15      edward snowden theres one trump loves vladimir...
# 16      booyah obama photographer hilariously trolls t...
# 17      ireland votes repeal abortion amendment landsl...
# ...                                                   ...
# 124970                           chris christie president
# 124978      gops old ploy tag president obama race baiter
# 124979  lawmakers introduce bill tackle misleadingly p...
# 124980                               dear president obama
# 124983                                       obama effect
#
#                                                 all_words
# 13      Trump's Crackdown On Immigrant Parents Puts Mo...
# 14      'Trump's Son Should Be Concerned': FBI Obtaine...
# 15      Edward Snowden: There's No One Trump Loves Mor...
# 16      Booyah: Obama Photographer Hilariously Trolls ...
# 17      Ireland Votes To Repeal Abortion Amendment In ...
# ...                                                   ...
# 124970  Why Chris Christie Should NOT Be President; Ap...
# 124978  GOP's Old Ploy: Tag President Obama as the Rac...
# 124979  Lawmakers Introduce Bill To Tackle Misleadingl...
# 124980  Dear President Obama; I'm assuming you are awa...
# 124983                                 The Obama Effect;
#
# [32739 rows x 6 columns]
#         category                                           headline  \
# 124989  WELLNESS                Why Overeating Doesn't Make You Fat
# 124990  WELLNESS  14 Habits Of People With A Healthy Relationshi...
# 124993  WELLNESS           5 Things That Could Be Stealing Your Joy
# 124994  WELLNESS                                Moments Make a Life
# 124996  WELLNESS                                          Fat Facts
# ...          ...                                                ...
# 200797  WELLNESS  Shoveling Snow? How to Protect Your Back (And ...
# 200799  WELLNESS  7 Reasons Working Too Much Is Bad For Your Health
# 200800  WELLNESS   The Sleep Library: 11 Soothing Books For Bedtime
# 200802  WELLNESS                   The Benefits of Caring for a Pet
# 200805  WELLNESS  This Is Only the Beginning: Surprising Advice ...
#
#                                                   authors  \
# 124989  Mark Hyman, MD, Contributor\nPracticing Physician
# 124990                                        Sarah Klein
# 124993  Amanda Gore, Contributor\nInternational keynot...
# 124994  Megan McDonough, Contributor\nCEO, Wholebeing ...
# 124996  Maria Rodale, Contributor\nCEO and Chairman of...
# ...                                                   ...
# 200797
# 200799                                        Sarah Klein
# 200800
# 200802  Rita Altman, R.N., Contributor\nSenior Vice Pr...
# 200805  Ellie Knaus, Contributor\nAtomic Moms Podcast ...
#
#                                         short_description  \
# 124989  If you take the right approach to ending your ...
# 124990  After a long list of rules and habits like the...
# 124993  Listen to yourself all day today -- are you an...
# 124994  Consciously constructing positive habits -- or...
# 124996  Human fat cells, photo by Dr. Peeke Here's how...
# ...                                                   ...
# 200797  Work up to it. Warm up inside, and incorporate...
# 200799  If you're the last one to leave the office, or...
# 200800  Do you toss and turn until you finally sit up ...
# 200802  For the young as well as the old, especially i...
# 200805  My great-aunt Ida loves to say, "This is only ...
#
#                                         lower_desc  \
# 124989                  overeating doesnt make fat
# 124990  14 habits people healthy relationship food
# 124993                 5 things could stealing joy
# 124994                           moments make life
# 124996                                   fat facts
# ...                                            ...
# 200797           shoveling snow protect back heart
# 200799           7 reasons working much bad health
# 200800     sleep library 11 soothing books bedtime
# 200802                         benefits caring pet
# 200805     beginning surprising advice centenarian
#
#                                                 all_words
# 124989  Why Overeating Doesn't Make You Fat; If you ta...
# 124990  14 Habits Of People With A Healthy Relationshi...
# 124993  5 Things That Could Be Stealing Your Joy; List...
# 124994  Moments Make a Life; Consciously constructing ...
# 124996  Fat Facts; Human fat cells, photo by Dr. Peeke...
# ...                                                   ...
# 200797  Shoveling Snow? How to Protect Your Back (And ...
# 200799  7 Reasons Working Too Much Is Bad For Your Hea...
# 200800  The Sleep Library: 11 Soothing Books For Bedti...
# 200802  The Benefits of Caring for a Pet; For the youn...
# 200805  This Is Only the Beginning: Surprising Advice ...
#
# [17827 rows x 6 columns]
#              category                                           headline  \
# 1       ENTERTAINMENT  Will Smith Joins Diplo And Nicky Jam For The 2...
# 2       ENTERTAINMENT    Hugh Grant Marries For The First Time At Age 57
# 3       ENTERTAINMENT  Jim Carrey Blasts 'Castrato' Adam Schiff And D...
# 4       ENTERTAINMENT  Julianna Margulies Uses Donald Trump Poop Bags...
# 5       ENTERTAINMENT  Morgan Freeman 'Devastated' That Sexual Harass...
# ...               ...                                                ...
# 200775  ENTERTAINMENT    Bow Wow Has Tax Liens From 2006, 2008, And 2010
# 200776  ENTERTAINMENT  World Preview Of Madonna's 'Give Me All Your L...
# 200777  ENTERTAINMENT  'Terminator 3' Star Nick Stahl Arrested For No...
# 200838  ENTERTAINMENT  Sundance, Ice-T, and Shades of the American Ra...
# 200839  ENTERTAINMENT  'Girl With the Dragon Tattoo' India Release Ca...
#
#                                                   authors  \
# 1                                           Andy McDonald
# 2                                              Ron Dicker
# 3                                              Ron Dicker
# 4                                              Ron Dicker
# 5                                              Ron Dicker
# ...                                                   ...
# 200775
# 200776
# 200777
# 200838  Courtney Garcia, Contributor\nI tell stories a...
# 200839
#
#                                         short_description  \
# 1                                Of course it has a song.
# 2       The actor and his longtime girlfriend Anna Ebe...
# 3       The actor gives Dems an ass-kicking for not fi...
# 4       The "Dietland" actress said using the bags is ...
# 5       "It is not right to equate horrific incidents ...
# ...                                                   ...
# 200775  Bow Wow needs to hire himself a new accountant...
# 200776  Fox and American Idol snagged the exclusive wo...
# 200777  Nick Stahl found himself a little short on cas...
# 200838  Representation of the collective diaspora has ...
# 200839  "Sony Pictures will not be releasing The Girl ...
#
#                                                lower_desc  \
# 1       smith joins diplo nicky jam 2018 world cups of...
# 2                    hugh grant marries first time age 57
# 3       jim carrey blasts castrato adam schiff democra...
# 4       julianna margulies uses donald trump poop bags...
# 5       morgan freeman devastated sexual harassment cl...
# ...                                                   ...
# 200775                   bow wow tax liens 2006 2008 2010
# 200776  world preview madonnas give luvin premiere ame...
# 200777  terminator 3 star nick stahl arrested paying c...
# 200838          sundance icet shades american race cinema
# 200839  girl dragon tattoo india release canceled loca...
#
#                                                 all_words
# 1       Will Smith Joins Diplo And Nicky Jam For The 2...
# 2       Hugh Grant Marries For The First Time At Age 5...
# 3       Jim Carrey Blasts 'Castrato' Adam Schiff And D...
# 4       Julianna Margulies Uses Donald Trump Poop Bags...
# 5       Morgan Freeman 'Devastated' That Sexual Harass...
# ...                                                   ...
# 200775  Bow Wow Has Tax Liens From 2006, 2008, And 201...
# 200776  World Preview Of Madonna's 'Give Me All Your L...
# 200777  'Terminator 3' Star Nick Stahl Arrested For No...
# 200838  Sundance, Ice-T, and Shades of the American Ra...
# 200839  'Girl With the Dragon Tattoo' India Release Ca...
#
# [16058 rows x 6 columns]
#        category                                           headline  \
# 126      TRAVEL  14 Ways To Make Family Road Trips Easier, From...
# 205      TRAVEL  14 Trips To Take From New York City On A Long ...
# 206      TRAVEL  Disney Reveals Opening Seasons For 'Star Wars'...
# 257      TRAVEL  Lonely Planet's Top European Destinations Of 2...
# 325      TRAVEL  8 Majestic Islands In Europe That Most Tourist...
# ...         ...                                                ...
# 200716   TRAVEL   The Hottest Places To Honeymoon In 2012 (PHOTOS)
# 200721   TRAVEL    Archaeo-Tourists Mob Ancient Aztec, Mayan Ruins
# 200723   TRAVEL         Traveling To The Roaring Twenties (PHOTOS)
# 200732   TRAVEL   Hiding From The Cold In A Quebecois Timber Lodge
# 200804   TRAVEL        Tea Time Beneath The Western Ghats (PHOTOS)
#
#                                                   authors  \
# 126                                        Taylor Pittman
# 205                                      Caroline Bologna
# 206                                              Ed Mazza
# 257                                         Brittany Nims
# 325                            PureWow, Editorial Partner
# ...                                                   ...
# 200716  Conde Nast Traveler, Contributor\nConde Nast T...
# 200721  Bob Schulman, Contributor\nTravel Editor, Watc...
# 200723  Black Tomato, Contributor\nCutting-edge travel...
# 200732             AFAR, Contributor\nExperiential Travel
# 200804  Stefani Jackenthal, Contributor\nAdventure Tra...
#
#                                         short_description  \
# 126     Having waterproof covers on the seats is kind ...
# 205     Charming towns, relaxing beaches and top hikin...
# 206     Star Wars: Galaxy's Edge will open at Disneyla...
# 257     These underrated travel destinations in Europe...
# 325     If you’re dreaming about a romantic European g...
# ...                                                   ...
# 200716  Unlike some travelers who wouldn't be caught d...
# 200721  They're checking out Chichen Itza, packing Pal...
# 200723  The fashion and film world is sticking a few j...
# 200732  I had come to ski some of the 65,000 acres of ...
# 200804  As we stepped out of the serene plantation, we...
#
#                                                lower_desc  \
# 126     14 ways make family road trips easier parents ...
# 205              14 trips take new york city long weekend
# 206     disney reveals opening seasons star wars theme...
# 257     lonely planets top european destinations 2018 ...
# 325      8 majestic islands europe tourists dont know yet
# ...                                                   ...
# 200716               hottest places honeymoon 2012 photos
# 200721      archaeotourists mob ancient aztec mayan ruins
# 200723                  traveling roaring twenties photos
# 200732                 hiding cold quebecois timber lodge
# 200804              tea time beneath western ghats photos
#
#                                                 all_words
# 126     14 Ways To Make Family Road Trips Easier, From...
# 205     14 Trips To Take From New York City On A Long ...
# 206     Disney Reveals Opening Seasons For 'Star Wars'...
# 257     Lonely Planet's Top European Destinations Of 2...
# 325     8 Majestic Islands In Europe That Most Tourist...
# ...                                                   ...
# 200716  The Hottest Places To Honeymoon In 2012 (PHOTO...
# 200721  Archaeo-Tourists Mob Ancient Aztec, Mayan Ruin...
# 200723  Traveling To The Roaring Twenties (PHOTOS); Th...
# 200732  Hiding From The Cold In A Quebecois Timber Lod...
# 200804  Tea Time Beneath The Western Ghats (PHOTOS); A...
#
# [9887 rows x 6 columns]
#               category                                           headline  \
# 125004  STYLE & BEAUTY  Things You Need To Know Before You Get A Tatto...
# 125005  STYLE & BEAUTY                   The Best Spring Colognes For Men
# 125017  STYLE & BEAUTY                             5 Fabulous Beauty Tips
# 125025  STYLE & BEAUTY                  Spring's Sexiest Peek-A-Boo Shoes
# 125034  STYLE & BEAUTY  Disney Princess Outfits Just Got A High Fashio...
# ...                ...                                                ...
# 200793  STYLE & BEAUTY             Camila Alves' Style Evolution (PHOTOS)
# 200795  STYLE & BEAUTY  This Blazer Was The Find Of The Century: From ...
# 200798  STYLE & BEAUTY  1 Girl, 4 Looks: Meet NYC's Hottest New Model,...
# 200801  STYLE & BEAUTY  Caroline Sieber And Lauren Santo Domingo In Lo...
# 200806  STYLE & BEAUTY               Cheryl Tiegs In A Sauna: A Look Back
#
#                                                   authors  \
# 125004               AskMen.com, Contributor\nContributor
# 125005
# 125017  Christina-Lauren Pollack, Contributor\nLifesty...
# 125025
# 125034                              Sara Roncero-Menendez
# ...                                                   ...
# 200793                                          Jada Wong
# 200795
# 200798
# 200801                                        Brooke Bobb
# 200806                                         Sarah Leon
#
#                                         short_description  \
# 125004  What's the number one thing you need to know a...
# 125005  Having a signature cologne shouldn't stop you ...
# 125017  Beauty tips that will instantly make you look ...
# 125025  When it comes to showing a little skin this sp...
# 125034  When fashion designers try their hand at a Dis...
# ...                                                   ...
# 200793  Camila Alves' style is proof that you don't ha...
# 200795  From De Lune: Another beautiful day here in NY...
# 200798  From Refinery29: When we tell you Lily Kwong i...
# 200801  WHAT: Two of the fashion industry's most styli...
# 200806  "A Look Back" is a daily column that highlight...
#
#                                                lower_desc  \
# 125004           things need know get tattoo youll regret
# 125005                           best spring colognes men
# 125017                             5 fabulous beauty tips
# 125025                     springs sexiest peekaboo shoes
# 125034  disney princess outfits got high fashion makeover
# ...                                                   ...
# 200793                camila alves style evolution photos
# 200795                        blazer find century network
# 200798  1 girl 4 looks meet nycs hottest new model lil...
# 200801  caroline sieber lauren santo domingo louis vui...
# 200806                       cheryl tiegs sauna look back
#
#                                                 all_words
# 125004  Things You Need To Know Before You Get A Tatto...
# 125005  The Best Spring Colognes For Men; Having a sig...
# 125017  5 Fabulous Beauty Tips; Beauty tips that will ...
# 125025  Spring's Sexiest Peek-A-Boo Shoes; When it com...
# 125034  Disney Princess Outfits Just Got A High Fashio...
# ...                                                   ...
# 200793  Camila Alves' Style Evolution (PHOTOS); Camila...
# 200795  This Blazer Was The Find Of The Century: From ...
# 200798  1 Girl, 4 Looks: Meet NYC's Hottest New Model,...
# 200801  Caroline Sieber And Lauren Santo Domingo In Lo...
# 200806  Cheryl Tiegs In A Sauna: A Look Back; "A Look ...
#
# [9649 rows x 6 columns]
#          category                                           headline  \
# 124992  PARENTING                           A Baby Book of Disasters
# 124995  PARENTING                       It's Time to Find Your Tribe
# 124997  PARENTING           Help HuffPost Parents Win A Webby Award!
# 125003  PARENTING  Why Our 'Imperfect' Moments Are Perfect to Our...
# 125007  PARENTING  Creatively Cope With Kids' Food Allergies This...
# ...           ...                                                ...
# 200726  PARENTING  Awesomely Geeky Dad Dicken Schrader Collaborat...
# 200738  PARENTING                                      Backyard Boys
# 200789  PARENTING                            With Friends Like These
# 200791  PARENTING    Confession: This Pediatrician Is a Sleep Softie
# 200807  PARENTING  Teen Responsibility Doesn't Happen -- It's Nur...
#
#                                                   authors  \
# 124992  Raquel D'Apice, Contributor\nStand-up comic an...
# 124995  Courtney Fitzgerald, Contributor\nMom, teacher...
# 124997
# 125003  Allison Tate, Contributor\nWriter, mother of four
# 125007  Kerry H. McManama, Contributor\nPro Communicat...
# ...                                                   ...
# 200726
# 200738  Janell Burley Hofmann, Contributor\nAuthor of ...
# 200789  Devon Corneal, Contributor\nMother, writer, la...
# 200791  Claire McCarthy, M.D., Contributor\nPediatrici...
# 200807  Gwenn Schurgin O'Keeffe, MD, Contributor\nPedi...
#
#                                         short_description  \
# 124992  Having a child is nothing if not a roller coas...
# 124995  I was just about to hang up my hat and decide ...
# 124997  HuffPost Parents has been nominated for a Webb...
# 125003  Mom was there. That's what is important. THAT'...
# 125007  While the physical ramifications of allergen i...
# ...                                                   ...
# 200726  All the ingredients for a classic embarrassing...
# 200738  Long before leadership courses, sensitivity tr...
# 200789  I didn't appreciate the freedom of introducing...
# 200791  This may not be a great confession to make as ...
# 200807  Do you feel kids today are as responsible as k...
#
#                                                lower_desc  \
# 124992                                baby book disasters
# 124995                                    time find tribe
# 124997              help huffpost parents win webby award
# 125003                 imperfect moments perfect children
# 125007         creatively cope kids food allergies easter
# ...                                                   ...
# 200726  awesomely geeky dad dicken schrader collaborat...
# 200738                                      backyard boys
# 200789                                       friends like
# 200791               confession pediatrician sleep softie
# 200807         teen responsibility doesnt happen nurtured
#
#                                                 all_words
# 124992  A Baby Book of Disasters; Having a child is no...
# 124995  It's Time to Find Your Tribe; I was just about...
# 124997  Help HuffPost Parents Win A Webby Award!; Huff...
# 125003  Why Our 'Imperfect' Moments Are Perfect to Our...
# 125007  Creatively Cope With Kids' Food Allergies This...
# ...                                                   ...
# 200726  Awesomely Geeky Dad Dicken Schrader Collaborat...
# 200738  Backyard Boys; Long before leadership courses,...
# 200789  With Friends Like These; I didn't appreciate t...
# 200791  Confession: This Pediatrician Is a Sleep Softi...
# 200807  Teen Responsibility Doesn't Happen -- It's Nur...
#
# [8677 rows x 6 columns]
#               category                                           headline  \
# 7578    HEALTHY LIVING  To The People Who Say ‘I’m Tired’ When Someone...
# 7693    HEALTHY LIVING  Eating Shake Shack Made Me Feel Healthier Than...
# 7747    HEALTHY LIVING  How To Stay Updated On The News Without Losing...
# 7927    HEALTHY LIVING  27 Perfect Tweets About Whole30 That Will Make...
# 7934    HEALTHY LIVING         The Real Reason Your Hands Are Always Cold
# ...                ...                                                ...
# 124913  HEALTHY LIVING  Why You Need Both a 'Bouncer' and a 'Bartender...
# 124914  HEALTHY LIVING  How Video Games Can Improve Dialogue on Mental...
# 124925  HEALTHY LIVING  Wake-Up Calls Inspired My Change From Overdriv...
# 124950  HEALTHY LIVING        Loving a Narcissist Without Losing Yourself
# 124988  HEALTHY LIVING                            Reasons Not to Be Happy
#
#                                                   authors  \
# 7578    The Mighty, ContributorWe face disability, dis...
# 7693    Colleen Werner, ContributorCampus Editor-at-Large
# 7747                                       Lindsay Holmes
# 7927                                       Lindsay Holmes
# 7934    Refinery29, ContributorThe #1 new-media brand ...
# ...                                                   ...
# 124913  Elizabeth Grace Saunders, ContributorFounder, ...
# 124914         Mona Shattell, Contributornurse researcher
# 124925  Jane Shure, ContributorLeadership Coach, Psych...
# 124950  Nancy Colier, ContributorPsychotherapist, inte...
# 124988  Mindy Utay, Contributor"Calming Life's Conflicts"
#
#                                         short_description  \
# 7578    When you feel like this, it’s important to kno...
# 7693    I can vividly remember the first time I felt f...
# 7747       Because it's only becoming more of a struggle.
# 7927    "The only Whole30 I want to participate in is ...
# 7934    Essentially, your hands are kept warm thanks t...
# ...                                                   ...
# 124913  Instead of judging whether you made the right ...
# 124914  While there are strong arguments for the games...
# 124925  My wake-up call marching orders were clear: No...
# 124950  It is very difficult for some people to see an...
# 124988  Our thoughts and feelings are powerful, but ma...
#
#                                                lower_desc  \
# 7578                     people say im tired someone asks
# 7693    eating shake shack made feel healthier dieting...
# 7747                stay updated news without losing mind
# 7927                   27 perfect tweets whole30 make lol
# 7934                        real reason hands always cold
# ...                                                   ...
# 124913     need bouncer bartender live happy healthy life
# 124914        video games improve dialogue mental illness
# 124925  wakeup calls inspired change overdrive sleep d...
# 124950                   loving narcissist without losing
# 124988                                      reasons happy
#
#                                                 all_words
# 7578    To The People Who Say ‘I’m Tired’ When Someone...
# 7693    Eating Shake Shack Made Me Feel Healthier Than...
# 7747    How To Stay Updated On The News Without Losing...
# 7927    27 Perfect Tweets About Whole30 That Will Make...
# 7934    The Real Reason Your Hands Are Always Cold; Es...
# ...                                                   ...
# 124913  Why You Need Both a 'Bouncer' and a 'Bartender...
# 124914  How Video Games Can Improve Dialogue on Mental...
# 124925  Wake-Up Calls Inspired My Change From Overdriv...
# 124950  Loving a Narcissist Without Losing Yourself; I...
# 124988  Reasons Not to Be Happy; Our thoughts and feel...
#
# [6694 rows x 6 columns]
#             category                                           headline  \
# 69      QUEER VOICES  'Queer Eye' Star Bobby Berk Gave Me A Desk Mak...
# 70      QUEER VOICES  Older Gay Men Try Out 'New Gay' Slang In This ...
# 71      QUEER VOICES  How 'RuPaul’s Drag Race' Is Teaching Straight ...
# 131     QUEER VOICES  Tig Notaro Tells Ellen DeGeneres About Her Son...
# 132     QUEER VOICES  Stormy Daniels Thanks ‘Wonderful Gay Dads’ As ...
# ...              ...                                                ...
# 200820  QUEER VOICES  Gay Divorce: How the Collaborative Family Law ...
# 200821  QUEER VOICES              Episode 87: Life Is a Highway (AUDIO)
# 200822  QUEER VOICES  Something To Celebrate: The Best LGBT Moments ...
# 200823  QUEER VOICES  Chris Gregoire, Washington State Governor, Dis...
# 200824  QUEER VOICES  Glenn Close On 'Albert Nobbs', Gender Bending ...
#
#                                                   authors  \
# 69                                  Gibson Johns, AOL.com
# 70                                         Curtis M. Wong
# 71                                INTO, Editorial Partner
# 131                                        Curtis M. Wong
# 132                               INTO, Editorial Partner
# ...                                                   ...
# 200820  Thomas Greenwald, Contributor\nPartner, Gorans...
# 200821  The Six Pack, Contributor\nRadio show hosted b...
# 200822
# 200823                  Michelangelo Signorile, Columnist
# 200824
#
#                                         short_description  \
# 69                                       Can you believe?
# 70               “You guys are watching too much RuPaul.”
# 71      Mainstream pop culture isn’t the only thing to...
# 131     The comedian also "can't wait" to play Jennife...
# 132     West Hollywood has also reaffirmed its commitm...
# ...                                                   ...
# 200820  One of the many unjust results of a state lega...
# 200821  On this episode of The Six Pack, we hit up the...
# 200822  Every other week we'll take a look at a few of...
# 200823  Regarding her own journey Gregoire said: “I wi...
# 200824  Twenty-four hours before the Golden Globes cer...
#
#                                                lower_desc  \
# 69      queer eye star bobby berk gave desk makeover i...
# 70        older gay men try new gay slang hilarious video
# 71      rupauls drag race teaching straight people que...
# 131     tig notaro tells ellen degeneres sons passion ...
# 132     stormy daniels thanks wonderful gay dads west ...
# ...                                                   ...
# 200820  gay divorce collaborative family law model hel...
# 200821                      episode 87 life highway audio
# 200822  something celebrate best lgbt moments week jan...
# 200823  chris gregoire washington state governor discu...
# 200824    glenn close albert nobbs gender bending damages
#
#                                                 all_words
# 69      'Queer Eye' Star Bobby Berk Gave Me A Desk Mak...
# 70      Older Gay Men Try Out 'New Gay' Slang In This ...
# 71      How 'RuPaul’s Drag Race' Is Teaching Straight ...
# 131     Tig Notaro Tells Ellen DeGeneres About Her Son...
# 132     Stormy Daniels Thanks ‘Wonderful Gay Dads’ As ...
# ...                                                   ...
# 200820  Gay Divorce: How the Collaborative Family Law ...
# 200821  Episode 87: Life Is a Highway (AUDIO); On this...
# 200822  Something To Celebrate: The Best LGBT Moments ...
# 200823  Chris Gregoire, Washington State Governor, Dis...
# 200824  Glenn Close On 'Albert Nobbs', Gender Bending ...
#
# [6314 rows x 6 columns]
#             category                                           headline  \
# 125019  FOOD & DRINK     Dallas Throws a Texas-size Wine and Food Party
# 125026  FOOD & DRINK  We Tasted The New Fruit Punch Oreos, So You Do...
# 125037  FOOD & DRINK  Yes, The Chia Seeds You Eat Are The Same Ones ...
# 125046  FOOD & DRINK  Farm to Fork Across America: Chef Tom Douglas,...
# 125059  FOOD & DRINK                                   The Whiskey Sour
# ...              ...                                                ...
# 200616  FOOD & DRINK  Frank's vs. Tabasco Buffalo: What's The Best W...
# 200626  FOOD & DRINK           10 Dips, Nibbles And Dishes For Game Day
# 200632  FOOD & DRINK     9 Korean Recipes: Go Outside Your Comfort Zone
# 200644  FOOD & DRINK                       5 Ways To Use Leftover Bread
# 200658  FOOD & DRINK              10 Recipes Made From Common Leftovers
#
#                                                   authors  \
# 125019  John Mariani, Contributor\nPublisher of Marian...
# 125026                                      Kristen Aiken
# 125037                                   Julie R. Thomson
# 125046  Julie Ann Fineman, Contributor\nCEO PeakPlate....
# 125059                    Food52, Contributor\nfood52.com
# ...                                                   ...
# 200616
# 200626  Jennifer Segal, Contributor\nChef, Cookbook Au...
# 200632                       Kitchen Daily, Kitchen Daily
# 200644                    Food52, Contributor\nfood52.com
# 200658                       Kitchen Daily, Kitchen Daily
#
#                                         short_description  \
# 125019                   Texas never does anything small.
# 125026                     Why are they doing this to us?
# 125037                          It's a little disturbing.
# 125046  Tom's benevolence doesn't stop at his kitchen ...
# 125059  The true sour is a study in simplicity -- of w...
# ...                                                   ...
# 200616  The two brands are embroiled in a marketing ca...
# 200626  Can't say I love football, but I always love h...
# 200632  Gochujang is a red chili paste that is made fr...
# 200644  There's a reason they call it the daily bread ...
# 200658  Everyone has their share of leftovers sitting ...
#
#                                                lower_desc  \
# 125019            dallas throws texassize wine food party
# 125026                  tasted new fruit punch oreos dont
# 125037             yes chia seeds eat ones grow chia pets
# 125046  farm fork across america chef tom douglas deli...
# 125059                                       whiskey sour
# ...                                                   ...
# 200616    franks vs tabasco buffalo whats best wing sauce
# 200626                    10 dips nibbles dishes game day
# 200632           9 korean recipes go outside comfort zone
# 200644                          5 ways use leftover bread
# 200658                   10 recipes made common leftovers
#
#                                                 all_words
# 125019  Dallas Throws a Texas-size Wine and Food Party...
# 125026  We Tasted The New Fruit Punch Oreos, So You Do...
# 125037  Yes, The Chia Seeds You Eat Are The Same Ones ...
# 125046  Farm to Fork Across America: Chef Tom Douglas,...
# 125059  The Whiskey Sour; The true sour is a study in ...
# ...                                                   ...
# 200616  Frank's vs. Tabasco Buffalo: What's The Best W...
# 200626  10 Dips, Nibbles And Dishes For Game Day; Can'...
# 200632  9 Korean Recipes: Go Outside Your Comfort Zone...
# 200644  5 Ways To Use Leftover Bread; There's a reason...
# 200658  10 Recipes Made From Common Leftovers; Everyon...
#
# [6226 rows x 6 columns]
#         category                                           headline  \
# 87      BUSINESS  U.S. Launches Auto Import Probe, China Vows To...
# 337     BUSINESS  Starbucks Says Anyone Can Now Sit In Its Cafes...
# 603     BUSINESS  Seattle Passes Controversial New Tax On City's...
# 604     BUSINESS  Uber Ends Forced Arbitration In Individual Cas...
# 669     BUSINESS  Chili's Hit By Data Breach, Credit And Debit C...
# ...          ...                                                ...
# 200833  BUSINESS  Four More Bank Closures Mark the Week of Janua...
# 200834  BUSINESS  Everything You Need To Know About Overdraft Fe...
# 200835  BUSINESS            Walmart Waving Goodbye To Some Greeters
# 200836  BUSINESS  At World Economic Forum, Fear of Global Contag...
# 200837  BUSINESS  Positive Customer Experience: What's the Retur...
#
#                                                   authors  \
# 87               David Shepardson and Jeff Mason, Reuters
# 337                                   Dominique Mosbergen
# 603                              Gregory Scruggs, Reuters
# 604                                            Emily Peck
# 669                                        Jenna Amatulli
# ...                                                   ...
# 200833  Dennis Santiago, Contributor\nGlobal Risk and ...
# 200834                                     Harry Bradford
# 200835
# 200836  Peter S. Goodman, Contributor\nExecutive Busin...
# 200837                Ernan Roman, Contributor\nPresident
#
#                                         short_description  \
# 87      The investigation could lead to new U.S. tarif...
# 337     The new policy was unveiled weeks after the co...
# 603     Following the council vote, Amazon’s vice pres...
# 604     Victims will be free to go to court -- but a f...
# 669     The breach is believed to have occurred betwee...
# ...                                                   ...
# 200833  The general pattern of the FDIC closing banks ...
# 200834  Don't like keeping all of your money stuffed u...
# 200835  After 30 years, "People Greeters" will no long...
# 200836  For decades, as crises have assailed developin...
# 200837  "Analysts at Adobe combined historical purchas...
#
#                                                lower_desc  \
# 87      us launches auto import probe china vows defen...
# 337     starbucks says anyone sit cafes even without b...
# 603     seattle passes controversial new tax citys big...
# 604     uber ends forced arbitration individual cases ...
# 669     chilis hit data breach credit debit card infor...
# ...                                                   ...
# 200833       four bank closures mark week january 27 2012
# 200834        everything need know overdraft fees graphic
# 200835                    walmart waving goodbye greeters
# 200836  world economic forum fear global contagion dom...
# 200837  positive customer experience whats return inve...
#
#                                                 all_words
# 87      U.S. Launches Auto Import Probe, China Vows To...
# 337     Starbucks Says Anyone Can Now Sit In Its Cafes...
# 603     Seattle Passes Controversial New Tax On City's...
# 604     Uber Ends Forced Arbitration In Individual Cas...
# 669     Chili's Hit By Data Breach, Credit And Debit C...
# ...                                                   ...
# 200833  Four More Bank Closures Mark the Week of Janua...
# 200834  Everything You Need To Know About Overdraft Fe...
# 200835  Walmart Waving Goodbye To Some Greeters; After...
# 200836  At World Economic Forum, Fear of Global Contag...
# 200837  Positive Customer Experience: What's the Retur...
#
# [5937 rows x 6 columns]
#        category                                           headline  \
# 37       COMEDY  Trump's New 'MAGA'-Themed Swimwear Sinks On Tw...
# 38       COMEDY  Seth Meyers Has 1 Funny Regret After Trump Can...
# 39       COMEDY  Colbert Wants To Turn NYC Subway Rides Into A ...
# 41       COMEDY  Jimmy Kimmel Knows Why Iran's Supreme Leader W...
# 78       COMEDY  'Late Night' Writer's Breathless Royal Wedding...
# ...         ...                                                ...
# 200810   COMEDY  Tim & Eric's 'Billion Dollar Movie Pledge' Sig...
# 200811   COMEDY  The Best Late Night Clips of the Week (VIDEO/P...
# 200812   COMEDY  Daily Show Correspondent Clip Of The Week: Al ...
# 200813   COMEDY       Mitt Romney Madness: Florida Edition (VIDEO)
# 200814   COMEDY                 7 Amazing Name Generators (PHOTOS)
#
#                                                   authors  \
# 37                                               Ed Mazza
# 38                                             Ron Dicker
# 39                                               Ed Mazza
# 41                                             Ron Dicker
# 78                                              Lee Moran
# ...                                                   ...
# 200810
# 200811  Matt Wilstein, Contributor\nEditor, Gotcha Med...
# 200812
# 200813                                           Ben Craw
# 200814                                         Seena Vali
#
#                                         short_description  \
# 37              "Does this swimsuit make me look racist?"
# 38          There goes the one token of his appreciation.
# 39      The "Late Show" host takes on Michael Cohen an...
# 41      The host reimagined the cartoon after Ayatolla...
# 78            “Then he bites his lip, like, ‘Hmm, girl.’”
# ...                                                   ...
# 200810  The pledge also asks its viewers to not see up...
# 200811  President Obama finally broke through the onsl...
# 200812  If you're like us, by the time Monday rolls ar...
# 200813  The apparent madness that gripped Mitt Romney ...
# 200814  Let's be honest: most of our names are pretty ...
#
#                                                lower_desc  \
# 37           trumps new magathemed swimwear sinks twitter
# 38      seth meyers 1 funny regret trump cancels north...
# 39      colbert wants turn nyc subway rides new terrib...
# 41      jimmy kimmel knows irans supreme leader watche...
# 78      late night writers breathless royal wedding re...
# ...                                                   ...
# 200810  tim erics billion dollar movie pledge signed p...
# 200811             best late night clips week videophotos
# 200812  daily show correspondent clip week al madrigal...
# 200813          mitt romney madness florida edition video
# 200814                   7 amazing name generators photos
#
#                                                 all_words
# 37      Trump's New 'MAGA'-Themed Swimwear Sinks On Tw...
# 38      Seth Meyers Has 1 Funny Regret After Trump Can...
# 39      Colbert Wants To Turn NYC Subway Rides Into A ...
# 41      Jimmy Kimmel Knows Why Iran's Supreme Leader W...
# 78      'Late Night' Writer's Breathless Royal Wedding...
# ...                                                   ...
# 200810  Tim & Eric's 'Billion Dollar Movie Pledge' Sig...
# 200811  The Best Late Night Clips of the Week (VIDEO/P...
# 200812  Daily Show Correspondent Clip Of The Week: Al ...
# 200813  Mitt Romney Madness: Florida Edition (VIDEO); ...
# 200814  7 Amazing Name Generators (PHOTOS); Let's be h...
#
# [5175 rows x 6 columns]
#        category                                           headline  \
# 80       SPORTS  Jets Chairman Christopher Johnson Won't Fine P...
# 101      SPORTS      Trump Posthumously Pardons Boxer Jack Johnson
# 135      SPORTS  Anna Kournikova Dancing With Her Bouncing Baby...
# 136      SPORTS  Trump Says NFL Players Unwilling To Stand For ...
# 154      SPORTS  Brandi Chastain Totally Agrees Her Hall Of Fam...
# ...         ...                                                ...
# 200786   SPORTS              Thank You James Dolan and Time Warner
# 200849   SPORTS  Maria Sharapova Stunned By Victoria Azarenka I...
# 200850   SPORTS  Giants Over Patriots, Jets Over Colts Among  M...
# 200851   SPORTS  Aldon Smith Arrested: 49ers Linebacker Busted ...
# 200852   SPORTS  Dwight Howard Rips Teammates After Magic Loss ...
#
#                                           authors  \
# 80                                     Ron Dicker
# 101                                Lydia O'Connor
# 135                                    Ron Dicker
# 136                    Doha Madani and Willa Frej
# 154                                     Lee Moran
# ...                                           ...
# 200786  Kelli Gail, Contributor\nFreelance writer
# 200849
# 200850
# 200851
# 200852
#
#                                         short_description  \
# 80      “I never want to put restrictions on the speec...
# 101     The pardoning of the black heavyweight boxer i...
# 135                               The score is love-love.
# 136     "I don’t think people should be staying in loc...
# 154     Was it supposed to be Gary Busey or Mickey Roo...
# ...                                                   ...
# 200786  Given the Knicks 7-13 record, James Dolan and ...
# 200849  Afterward, Azarenka, more effusive with the pr...
# 200850  Leading up to Super Bowl XLVI, the most talked...
# 200851  CORRECTION: An earlier version of this story i...
# 200852  The five-time all-star center tore into his te...
#
#                                                lower_desc  \
# 80      jets chairman christopher johnson wont fine pl...
# 101         trump posthumously pardons boxer jack johnson
# 135     anna kournikova dancing bouncing baby cutest t...
# 136     trump says nfl players unwilling stand anthem ...
# 154     brandi chastain totally agrees hall fame plaqu...
# ...                                                   ...
# 200786                      thank james dolan time warner
# 200849  maria sharapova stunned victoria azarenka aust...
# 200850  giants patriots jets colts among improbable su...
# 200851   aldon smith arrested 49ers linebacker busted dui
# 200852    dwight howard rips teammates magic loss hornets
#
#                                                 all_words
# 80      Jets Chairman Christopher Johnson Won't Fine P...
# 101     Trump Posthumously Pardons Boxer Jack Johnson;...
# 135     Anna Kournikova Dancing With Her Bouncing Baby...
# 136     Trump Says NFL Players Unwilling To Stand For ...
# 154     Brandi Chastain Totally Agrees Her Hall Of Fam...
# ...                                                   ...
# 200786  Thank You James Dolan and Time Warner; Given t...
# 200849  Maria Sharapova Stunned By Victoria Azarenka I...
# 200850  Giants Over Patriots, Jets Over Colts Among  M...
# 200851  Aldon Smith Arrested: 49ers Linebacker Busted ...
# 200852  Dwight Howard Rips Teammates After Magic Loss ...
#
# [4884 rows x 6 columns]
#             category                                           headline  \
# 27      BLACK VOICES  Warriors Coach Steve Kerr Calls NFL Ban On Pro...
# 28      BLACK VOICES  In Historic Victory, Barbados Elects First Fem...
# 29      BLACK VOICES  Police Killed At Least 378 Black Americans Fro...
# 31      BLACK VOICES    BET Chairman and CEO Debra Lee Is Stepping Down
# 88      BLACK VOICES  This Women Pulled Out All The Stops To Land He...
# ...              ...                                                ...
# 200748  BLACK VOICES  UNCF Honors Students With "An Evening With The...
# 200749  BLACK VOICES           Oprah Winfrey's Style Evolution (PHOTOS)
# 200750  BLACK VOICES  Max Hardy, Amare Stoudemire's Personal Chef, A...
# 200751  BLACK VOICES                                Darkness Ain't Cool
# 200752  BLACK VOICES         Would Martin Luther Vote for Barack Obama?
#
#                                                   authors  \
# 27                                      Sebastian Murdock
# 28                                            Kenya Downs
# 29                                      Sebastian Murdock
# 31                                      Carla Baranauckas
# 88                                         Jenna Amatulli
# ...                                                   ...
# 200748
# 200749                                       Julee Wilson
# 200750                       Jessica Cumberbatch Anderson
# 200751         Alisha L. Gordon, Contributor\nContributor
# 200752  William E. Flippin, Jr., Contributor\nAdvocate...
#
#                                         short_description  \
# 27      Forbidding players to take a knee during the n...
# 28      Mia Amor Mottley even earned the backing of th...
# ...
# 19359   What If Every School Had This Sign?; The Welco...
# 21135   Tiny Seal Pup Found Tangled In Fishing Net Sav...
# 22071   North Carolina Cops Respond To Party Complaint...
# 22380   See The Slick Moves That Got India's 'Billy El...
# 22497   Secrets To A Happy Marriage From A 99-Year-Old...
# ...                                                   ...
# 124167  Brave: Hearts, Mended; Paris was half of one o...
# 124277  These Kids Thought Their School Lacked A Place...
# 124374  Purritos = Cats, Burritos, The Internet. All O...
# 124466  Blind People Describe Beauty As 'Joy,' 'Truth,...
# 124654  Earth Day Project Collecting 1 Million Differe...
#
# [1398 rows x 6 columns]
#            category                                           headline  \
# 125421  ENVIRONMENT  Sky Vets Perform Incredible Rescue To Save Wil...
# 125422  ENVIRONMENT  Animal Photos Of The Week: Baby Panda Goes For...
# 125423  ENVIRONMENT  Washington Mudslide Menacing Fabled Pacific No...
# 125424  ENVIRONMENT  America's Exotic Pet Obsession Is Out Of Contr...
# 125494  ENVIRONMENT             Time to Leave Our Bad Carbon Boyfriend
# ...             ...                                                ...
# 200828  ENVIRONMENT  Boxer Puppy And Cows Make Friends During Walk ...
# 200829  ENVIRONMENT  'Black Smoker' Vents: New Species Discovered N...
# 200830  ENVIRONMENT                      Green Activists: 50 And Older
# 200831  ENVIRONMENT  Winter Weather Photo Contest: Submit Your Own ...
# 200832  ENVIRONMENT          Insects Top Newly Discovered Species List
#
#                                                   authors  \
# 125421                                    Brianna Elliott
# 125422
# 125423                                   Reuters, Reuters
# 125424                                    Brianna Elliott
# 125494  Bob Brinkmann, Contributor\nProfessor of Geolo...
# ...                                                   ...
# 200828
# 200829
# 200830
# 200831
# 200832
#
#                                         short_description  \
# 125421  Warning: This video contains graphic images of...
# 125422  This week has been an interesting one in the w...
# 125423  The tribe - whose name means "the river people...
# 125424  Nearly two-thirds of Americans own at least on...
# 125494  But break-ups happen all the time and we find ...
# ...                                                   ...
# 200828  This bevy of otters were also filmed having a ...
# 200829  Photos and captions courtesy of University of ...
# 200830  If you look at some of today's most prominent ...
# 200831  While severe winter weather has devastated som...
# 200832  Species IDs need improvement In addition to th...
#
#                                                lower_desc  \
# 125421  sky vets perform incredible rescue save wild l...
# 125422          animal photos week baby panda goes stroll
# 125423  washington mudslide menacing fabled pacific no...
# 125424  americas exotic pet obsession control photos v...
# 125494                    time leave bad carbon boyfriend
# ...                                                   ...
# 200828  boxer puppy cows make friends walk newcastle v...
# 200829  black smoker vents new species discovered near...
# 200830                           green activists 50 older
# 200831       winter weather photo contest submit pictures
# 200832          insects top newly discovered species list
#
#                                                 all_words
# 125421  Sky Vets Perform Incredible Rescue To Save Wil...
# 125422  Animal Photos Of The Week: Baby Panda Goes For...
# 125423  Washington Mudslide Menacing Fabled Pacific No...
# 125424  America's Exotic Pet Obsession Is Out Of Contr...
# 125494  Time to Leave Our Bad Carbon Boyfriend; But br...
# ...                                                   ...
# 200828  Boxer Puppy And Cows Make Friends During Walk ...
# 200829  'Black Smoker' Vents: New Species Discovered N...
# 200830  Green Activists: 50 And Older; If you look at ...
# 200831  Winter Weather Photo Contest: Submit Your Own ...
# 200832  Insects Top Newly Discovered Species List; Spe...
#
# [1323 rows x 6 columns]
#        category                                           headline  \
# 6109    COLLEGE  Cornell Frat's 'Pig Roast' Gave Points For Sex...
# 8649    COLLEGE  Norm Pattiz, Accused Of Sexual Harassment, To ...
# 9855    COLLEGE  Radio Mogul Under Pressure To Resign From Powe...
# 13213   COLLEGE           When ICE Comes Calling In The Ivy League
# 13701   COLLEGE  As College Costs Rise, Congress Must Save The ...
# ...         ...                                                ...
# 124784  COLLEGE  How Much College Football Players Should Be Ma...
# 124786  COLLEGE  How To Figure Out What You Really Want To Do I...
# 124843  COLLEGE                             Bowdoin's Double Bogey
# 124912  COLLEGE  Why Being Rejected By Your Dream School Isn't ...
# 124965  COLLEGE  'The Only Way I Can Do This Research Project I...
#
#                                                   authors  \
# 6109                                           Ron Dicker
# 8649                                       Carla Herreria
# 9855                                          Matt Ferner
# 13213   Center for Community Change Action, Contributo...
# 13701   Rep. Terri Sewell, ContributorRep. Terri A. Se...
# ...                                                   ...
# 124784
# 124786
# 124843  Peter W. Wood, ContributorPresident of the Nat...
# 124912                                       Jessica Kane
# 124965                                   Allison Bresnick
#
#                                         short_description  \
# 6109            Zeta Beta Tau was slapped with probation.
# 8649    The media executive submitted his resignation ...
# 9855    Several women have accused Norman Pattiz of se...
# 13213                                     We must resist.
# 13701   In today’s highly competitive global economy, ...
# ...                                                   ...
# 124784
# 124786
# 124843  This is American higher education today: an an...
# 124912
# 124965
#
#                                                lower_desc  \
# 6109    cornell frats pig roast gave points sex heavie...
# 8649    norm pattiz accused sexual harassment resign u...
# 9855    radio mogul pressure resign powerful californi...
# 13213                        ice comes calling ivy league
# 13701   college costs rise congress must save perkins ...
# ...                                                   ...
# 124784               much college football players making
# 124786                            figure really want life
# 124843                              bowdoins double bogey
# 124912               rejected dream school isnt end world
# 124965               way research project become stripper
#
#                                                 all_words
# 6109    Cornell Frat's 'Pig Roast' Gave Points For Sex...
# 8649    Norm Pattiz, Accused Of Sexual Harassment, To ...
# 9855    Radio Mogul Under Pressure To Resign From Powe...
# 13213   When ICE Comes Calling In The Ivy League; We m...
# 13701   As College Costs Rise, Congress Must Save The ...
# ...                                                   ...
# 124784  How Much College Football Players Should Be Ma...
# 124786  How To Figure Out What You Really Want To Do I...
# 124843  Bowdoin's Double Bogey; This is American highe...
# 124912  Why Being Rejected By Your Dream School Isn't ...
# 124965  'The Only Way I Can Do This Research Project I...
#
# [1144 rows x 6 columns]
#              category                                           headline  \
# 258     LATINO VOICES  Attorney Aaron Schlossberg Insists Anti-Spanis...
# 351     LATINO VOICES  Protesters Throw A Fiesta To Razz Lawyer Who R...
# 456     LATINO VOICES  Latino Man Insulted When Starbucks Barista Wri...
# 543     LATINO VOICES  Angry White Dude's Rant About People Speaking ...
# 1472    LATINO VOICES  Trump Asks If There Are Hispanics In The Room ...
# ...               ...                                                ...
# 124413  LATINO VOICES  LOOK: Latin Billboard Music Awards Fashion Hit...
# 124434  LATINO VOICES  Are Deportations Rising or Falling? A Focus on...
# 124624  LATINO VOICES  When I Chose to Stop Feeling Small: The Story ...
# 124644  LATINO VOICES     More Latino Than White Students Admitted To UC
# 124667  LATINO VOICES        Living and Breathing Gabriel García Márquez
#
#                                                   authors  \
# 258                                            David Moye
# 351                                        Mary Papenfuss
# 456                                            David Moye
# 543                                            David Moye
# 1472                                    Sebastian Murdock
# ...                                                   ...
# 124413                                    Carolina Moreno
# 124434  Laura E. Enriquez, ContributorAssistant Profes...
# 124624  Laura Elizabeth Hernandez, ContributorWriter a...
# 124644                                     Lydia O'Connor
# 124667  Elio Leturia, ContributorAssociate Professor, ...
#
#                                         short_description  \
# 258     In the apology, Aaron Schlossberg claims he mo...
# 351     Aaron Schlossberg was treated to outrage, mari...
# 456     The coffee giant tried to apologize with a $50...
# 543     The man tells an employee “Your staff is speak...
# 1472    Once he made sure the coast was clear, he gave...
# ...                                                   ...
# 124413
# 124434  Although clear and correct statistics are no d...
# 124624  No woman in my family had ever been this tall,...
# 124644
# 124667  Thirty years ago I lived García Márquez. Maybe...
#
#                                                lower_desc  \
# 258     attorney aaron schlossberg insists antispanish...
# 351     protesters throw fiesta razz lawyer ranted spa...
# 456     latino man insulted starbucks barista writes s...
# 543     angry white dudes rant people speaking spanish...
# 1472             trump asks hispanics room demanding wall
# ...                                                   ...
# 124413  look latin billboard music awards fashion hit ...
# 124434  deportations rising falling focus people affected
# 124624  chose stop feeling small story latina amazon w...
# 124644                  latino white students admitted uc
# 124667            living breathing gabriel garcía márquez
#
#                                                 all_words
# 258     Attorney Aaron Schlossberg Insists Anti-Spanis...
# 351     Protesters Throw A Fiesta To Razz Lawyer Who R...
# 456     Latino Man Insulted When Starbucks Barista Wri...
# 543     Angry White Dude's Rant About People Speaking ...
# 1472    Trump Asks If There Are Hispanics In The Room ...
# ...                                                   ...
# 124413  LOOK: Latin Billboard Music Awards Fashion Hit...
# 124434  Are Deportations Rising or Falling? A Focus on...
# 124624  When I Chose to Stop Feeling Small: The Story ...
# 124644   More Latino Than White Students Admitted To UC;
# 124667  Living and Breathing Gabriel García Márquez; T...
#
# [1129 rows x 6 columns]
#          category                                           headline  \
# 443     EDUCATION  The Controversial Way Some California Schools ...
# 1255    EDUCATION  California School First In The Nation To Be Di...
# 1346    EDUCATION  States Are Favoring School Choice At A Steep C...
# 1380    EDUCATION  Girls Reportedly Bleeding Through Pants Due To...
# 1978    EDUCATION  Desperate For Teachers, Districts Beg Retirees...
# ...           ...                                                ...
# 124610  EDUCATION  The Global Search for Education:  The School o...
# 124660  EDUCATION                        Brainstorming Middle School
# 124663  EDUCATION  Staunch Majority of California Voters Support ...
# 124822  EDUCATION  Why Doesn't the New York Times Understand the ...
# 124964  EDUCATION         My Son Only Read One Book in Middle School
#
#                                                   authors  \
# 443                           EdSource, Editorial Partner
# 1255                          EdSource, Editorial Partner
# 1346               The Conversation US, Editorial Partner
# 1380                                          Doha Madani
# 1978              The Hechinger Report, Editorial Partner
# ...                                                   ...
# 124610  C. M. Rubin, ContributorBlogger and author, 'T...
# 124660  Allison Gaines Pell, ContributorHead of School...
# 124663      Deborah Kong, ContributorDirector, Early Edge
# 124822  Diane Ravitch, ContributorResearch Professor o...
# 124964                     Franchesca Warren, Contributor
#
#                                         short_description  \
# 443     By David Washburn The two 9th-grade girls hear...
# 1255    By David Washburn Among the many disturbing tr...
# 1346    The current debate over school funding must mo...
# 1380    The school system is now allowing girls to tie...
# 1978    "It’s difficult not to respond when you hear t...
# ...                                                   ...
# 124610
# 124660  If we want our children to help us preserve, s...
# 124663  Through these proposals, we can provide every ...
# 124822  How can the nation's "newspaper of record" be ...
# 124964  Great reading can be done in middle school if ...
#
#                                                lower_desc  \
# 443     controversial way california schools handling ...
# 1255    california school first nation digitally mappe...
# 1346    states favoring school choice steep cost publi...
# 1380    girls reportedly bleeding pants due charter sc...
# 1978    desperate teachers districts beg retirees come...
# ...                                                   ...
# 124610              global search education school future
# 124660                        brainstorming middle school
# 124663    staunch majority california voters support prek
# 124822  doesnt new york times understand controversy c...
# 124964                    son read one book middle school
#
#                                                 all_words
# 443     The Controversial Way Some California Schools ...
# 1255    California School First In The Nation To Be Di...
# 1346    States Are Favoring School Choice At A Steep C...
# 1380    Girls Reportedly Bleeding Through Pants Due To...
# 1978    Desperate For Teachers, Districts Beg Retirees...
# ...                                                   ...
# 124610  The Global Search for Education:  The School o...
# 124660  Brainstorming Middle School; If we want our ch...
# 124663  Staunch Majority of California Voters Support ...
# 124822  Why Doesn't the New York Times Understand the ...
# 124964  My Son Only Read One Book in Middle School; Gr...
#
# [1004 rows x 6 columns]

# %% [markdown]
# ### Make Target and features DFs

# %%
y = df.category

# %%
X = df.drop('category', axis=1)

# %% [markdown]
# ### Get list of stop words

# %%
# generate a list of stopwords for TfidfVectorizer to ignore
stopwords_list = stopwords.words('english') + list(string.punctuation)

# %% [markdown]
# ## EDA

# %% [markdown]
# ### Basic cleaning

# %%
#lower case
df['lower_desc'] = df['headline'].apply(lambda x: " ".join(x.lower() for x in x.split()))

# %%
#remove punctuation
df['lower_desc'] = df['lower_desc'].str.replace('[^\w\s]','')
# Out:
# <ipython-input-111-9688f174aeb7>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['lower_desc'] = df['lower_desc'].str.replace('[^\w\s]','')

# %%
#stopword gathering and removal
stop = stopwords.words('english')
df['lower_desc'] = df['lower_desc'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))

# %% [markdown]
# ### Tokenize

# %%
desc_str = ' '.join(df['lower_desc'].tolist())
print(desc_str)
tokens = nltk.word_tokenize(desc_str) #tokenizing 
print(len(tokens))
# Out:
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# 1349444

# %% [markdown]
# ### Pos tagging

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/willcline/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
tokens_pos = nltk.pos_tag(tokens)
pos_df = pd.DataFrame(tokens_pos, columns = ('word','POS'))
pos_sum = pos_df.groupby('POS', as_index=False).count() # group by POS tags
pos_sum.sort_values(['word'], ascending=[False]) # in descending order of number of words per tag

# %%
#getting just the nouns
filtered_pos = [ ]
for one in tokens_pos:
    if one[1] == 'NN' or one[1] == 'NNS' or one[1] == 'NNP' or one[1] == 'NNPS':
        filtered_pos.append(one)
print (len(filtered_pos))

# %%
#the 100 most common nouns
fdist_pos = nltk.FreqDist(filtered_pos)
top_100_words = fdist_pos.most_common(100)
print(top_100_words)

# %%
top_words_df = pd.DataFrame(top_100_words, columns = ('pos','count'))
top_words_df['Word'] = top_words_df['pos'].apply(lambda x: x[0]) # split the tuple of POS
top_words_df = top_words_df.drop('pos', 1) # drop the previous column
top_words_df.head(10)

# %%
fig, ax = plt.subplots(figsize=(15,18))
top_words_df.sort_values(by='count').plot.barh(x='Word',
                      y='count',
                      ax=ax,
                      color="purple")

ax.set_title("Common Words Found in DS Job Descriptions(Without Stop Words)")

plt.show()

# %% [markdown]
# ### Vectorize data with tf-idf(one of the 3 vectorizer methods) and make a train test split

# %%
# generate tf-idf vectorization (use sklearn's TfidfVectorizer) for our data
def tfidf(X, y,  stopwords_list): 
    X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
    vectorizer = TfidfVectorizer(stop_words=stopwords_list)
    tf_idf_train = vectorizer.fit_transform(X_train)
    tf_idf_test = vectorizer.transform(X_test)
    return tf_idf_train, tf_idf_test, y_train, y_test, vectorizer

# %%
#Call above function to vectorize and train test split data and put them in variables.
#Up here because presumably only have to do it once
idf_train, idf_test, y_tr, y_t, vectorizer = tfidf(X['headline'], y, stopwords_list)

# %%
idf_train.todense()

# %% [markdown]
# ### Prediction function

# %%
def classify_text(classifier, tf_idf_train, tf_idf_test, y_train):
    classifier.fit(tf_idf_train, y_train)
    train_preds = classifier.predict(tf_idf_train)
    test_preds = classifier.predict(tf_idf_test)
    return train_preds, test_preds

# %% [markdown]
# ### Scoring function to score predictions

# %%
def score_preds(y_test,y_train,test_preds, train_preds):
    print("Train: ", accuracy_score(y_train, train_preds))
    print("Test: ", accuracy_score(y_test, test_preds))
#     confusion_matrix(y_test, test_preds)
#     confusion_matrix(y_train, train_preds)

# %% [markdown]
# ### Make baseline RF and NB models

# %%
rfc = RandomForestClassifier(n_estimators=100)
nb_classifier = MultinomialNB()

# %%
idf_train.shape

# %%
y_t.shape

# %%
#Call function using results of vectorize function using NB model
nb_train_preds, nb_test_preds = classify_text(nb_classifier, idf_train, idf_test, y_tr)

# %%
#Call function for score
score_preds(y_t, y_tr, nb_test_preds, nb_train_preds)

# %%
#Call function using results of vectorize function using RF model
rf_train_preds, rf_test_preds = classify_text(rfc, idf_train, idf_test, y_tr)

# %%
#Call function for score
score_preds(y_t, y_tr, rf_test_preds, rf_train_preds)
