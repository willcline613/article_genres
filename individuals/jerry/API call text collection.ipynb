# %%
# !pip3 install newspaper3k

# %%
from newspaper import Article

# %%
link = "https://www.huffingtonpost.com/entry/justin-timberlake-visits-texas-school-shooting-victims_us_5b098161e4b0fdb2aa54167e"

# %%
article = Article(link)

# %%
article.download()

# %%
article.html
# Out:
# '<!DOCTYPE html>\n<html lang="en">\n<head>\n\n<script type="text/javascript">window.NREUM||(NREUM={});NREUM.info={"beacon":"bam-cell.nr-data.net","errorBeacon":"bam-cell.nr-data.net","licenseKey":"a2134792db","applicationID":"36240457","transactionName":"dApeRxcOWV5RFB1SA0QORFwVTlBcQBRbUxUYFlhcEg==","queueTime":1,"applicationTime":55,"agent":"","atts":"TEdFEV8aF1dQD0ZfCVlHChEQEhceFhVXVRJeCl4RX0NwXEADQEIHXgtdVgsVF09J"}</script>\n<script type="text/javascript">(window.NREUM||(NREUM={})).loader_config={licenseKey:"a2134792db",applicationID:"36240457"};window.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var i=e[n]={exports:{}};t[n][0].call(i.exports,function(e){var i=t[n][1][e];return r(i||e)},i,i.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var i=0;i<n.length;i++)r(n[i]);return r}({1:[function(t,e,n){function r(){}function i(t,e,n){return function(){return o(t,[u.now()].concat(f(arguments)),e?null:this,n),e?void 0:this
# ...

# %%
article.parse()

# %%
article.authors
# Out:
# ['Senior Reporter']

# %%
article.publish_date
# Out:
# datetime.datetime(2018, 5, 26, 12, 47, 57, tzinfo=tzoffset(None, -14400))

# %%
article.text.replace("\n", "")
# Out:
# 'Justin Timberlake paid a visit Friday to victims of last week’s school shooting in Santa Fe, Texas.He dropped in at an area hospital where victims were recovering from the shooting at Santa Fe High School, in which a gunman killed 10 people and injured 13 last Friday.The visit came a couple days after the pop icon performed a concert in nearby Houston in which he donned a “Santa Fe Strong” shirt, the Houston Chronicle reported.A Facebook post from Sonia Lopez-Puentes, the mother of injured student Sarah Salazar, shows a picture of Timberlake with Salazar at the hospital and says he brought her a gift.Timberlake was seen sitting with J.J. Watt at the Houston Rockets game on Thursday night. Watt, a star defensive end for the Houston Texans, recently pledged to pay for the funerals of those killed.'

# %%
import json
import pandas as pd
import numpy as np

# %%
df = pd.read_json("../../data/News_Category_Dataset_v2.json", lines = True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-2463f05c718d> in <module>
# ----> 1 df = pd.read_json("../../data/News_Category_Dataset_v2.json", lines = True)
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     197                 else:
#     198                     kwargs[new_arg_name] = new_arg_value
# --> 199             return func(*args, **kwargs)
#     200
#     201         return cast(F, wrapper)
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     294                 )
#     295                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 296             return func(*args, **kwargs)
#     297
#     298         return wrapper
#
# ...

# %%
len(df.iloc[0:3, :])
# Out:
# 3

# %%
df["link"].iloc[100001:]
# Out:
# 100001    https://www.huffingtonpost.com/entry/2016-pres...
# 100002    https://www.huffingtonpost.com/entry/immigrati...
# 100003    https://www.huffingtonpost.com/entry/uva-soror...
# 100004    https://www.huffingtonpost.com/entry/bart-zomb...
# 100005    https://www.huffingtonpost.com/entry/the-super...
#                                 ...
# 200848    https://www.huffingtonpost.com/entry/rim-ceo-t...
# 200849    https://www.huffingtonpost.com/entry/maria-sha...
# 200850    https://www.huffingtonpost.com/entry/super-bow...
# 200851    https://www.huffingtonpost.com/entry/aldon-smi...
# 200852    https://www.huffingtonpost.com/entry/dwight-ho...
# Name: link, Length: 100852, dtype: object

# %%
df["link"][0]
# Out:
# 'https://www.huffingtonpost.com/entry/texas-amanda-painter-mass-shooting_us_5b081ab4e4b0802d69caad89'

# %%
import time

# %%
# !pip install ratelimit

# %%
df_2 = pd.DataFrame()

x = 100001
articles = []
for i in df["link"].iloc[100001:110001]:
    article = Article(i)
    try:
        article.download()
        article.parse()
        articles.append((df["headline"][x], article.text.replace("\n", " ")))
    except:
        articles.append((df["headline"][x], np.nan))
    x += 1
    if x%5 == True:
        time.sleep(5)
        print(x - 100000, " done")
# Out:
# 6  done
# 11  done
# 16  done
# 21  done
# 26  done
# 31  done
# 36  done
# 41  done
# 46  done
# 51  done
# 56  done
# 61  done
# 66  done
# 71  done
# 76  done
# 81  done
# 86  done
# 91  done
# 96  done
# 101  done
# 106  done
# 111  done
# 116  done
# 121  done
# 126  done
# 131  done
# 136  done
# 141  done
# 146  done
# 151  done
# 156  done
# 161  done
# 166  done
# 171  done
# 176  done
# 181  done
# 186  done
# 191  done
# 196  done
# 201  done
# 206  done
# 211  done
# 216  done
# 221  done
# 226  done
# 231  done
# 236  done
# 241  done
# 246  done
# 251  done
# 256  done
# 261  done
# 266  done
# 271  done
# 276  done
# 281  done
# 286  done
# 291  done
# 296  done
# 301  done
# 306  done
# 311  done
# 316  done
# 321  done
# 326  done
# 331  done
# 336  done
# 341  done
# 346  done
# 351  done
# 356  done
# 361  done
# 366  done
# 371  done
# 376  done
# 381  done
# 386  done
# 391  done
# 396  done
# 401  done
# 406  done
# 411  done
# 416  done
# 421  done
# 426  done
# ...

# %%
articles[-1]
# Out:
# ('How Marketers Should Appeal to Women',
# ...

# %%
df["headline"].iloc[110001]
# Out:
# 'Does Social Media Ruin Relationships?'

# %%
x = 110001
articles_1 = []
for i in df["link"].iloc[110001:120001]:
    article = Article(i)
    try:
        article.download()
        article.parse()
        articles_1.append((df["headline"][x], article.text.replace("\n", " ")))
    except:
        articles_1.append((df["headline"][x], np.nan))
    x += 1
    if x%5 == True:
        time.sleep(5)
        print(x - 100000, " done")
# Out:
# 10006  done
# 10011  done
# 10016  done
# 10021  done
# 10026  done
# 10031  done
# 10036  done
# 10041  done
# 10046  done
# 10051  done
# 10056  done
# 10061  done
# 10066  done
# 10071  done
# 10076  done
# 10081  done
# 10086  done
# 10091  done
# 10096  done
# 10101  done
# 10106  done
# 10111  done
# 10116  done
# 10121  done
# 10126  done
# 10131  done
# 10136  done
# 10141  done
# 10146  done
# 10151  done
# 10156  done
# 10161  done
# 10166  done
# 10171  done
# 10176  done
# 10181  done
# 10186  done
# 10191  done
# 10196  done
# 10201  done
# 10206  done
# 10211  done
# 10216  done
# 10221  done
# 10226  done
# 10231  done
# 10236  done
# 10241  done
# 10246  done
# 10251  done
# 10256  done
# 10261  done
# 10266  done
# 10271  done
# 10276  done
# 10281  done
# 10286  done
# 10291  done
# 10296  done
# 10301  done
# 10306  done
# 10311  done
# 10316  done
# 10321  done
# 10326  done
# 10331  done
# 10336  done
# 10341  done
# 10346  done
# 10351  done
# 10356  done
# ...

# %%
x = 120001
articles_2 = []
for i in df["link"].iloc[120001:130001]:
    article = Article(i)
    try:
        article.download()
        article.parse()
        articles_2.append((df["headline"][x], article.text.replace("\n", " ")))
    except:
        articles_2.append((df["headline"][x], np.nan))
    x += 1
    if x%5 == True:
        time.sleep(5)
        print(x - 100000, " done")
# Out:
# 20006  done
# 20011  done
# 20016  done
# 20021  done
# 20026  done
# 20031  done
# 20036  done
# 20041  done
# 20046  done
# 20051  done
# 20056  done
# 20061  done
# 20066  done
# 20071  done
# 20076  done
# 20081  done
# 20086  done
# 20091  done
# 20096  done
# 20101  done
# 20106  done
# 20111  done
# 20116  done
# 20121  done
# 20126  done
# 20131  done
# 20136  done
# 20141  done
# 20146  done
# 20151  done
# 20156  done
# 20161  done
# 20166  done
# 20171  done
# 20176  done
# 20181  done
# 20186  done
# 20191  done
# 20196  done
# 20201  done
# 20206  done
# 20211  done
# 20216  done
# 20221  done
# 20226  done
# 20231  done
# 20236  done
# 20241  done
# 20246  done
# 20251  done
# 20256  done
# 20261  done
# 20266  done
# 20271  done
# 20276  done
# 20281  done
# 20286  done
# 20291  done
# 20296  done
# 20301  done
# 20306  done
# 20311  done
# 20316  done
# 20321  done
# 20326  done
# 20331  done
# 20336  done
# 20341  done
# 20346  done
# 20351  done
# 20356  done
# ...

# %%
x = 130001
articles_3 = []
for i in df["link"].iloc[130001:140001]:
    article = Article(i)
    try:
        article.download()
        article.parse()
        articles_3.append((df["headline"][x], article.text.replace("\n", " ")))
    except:
        articles_3.append((df["headline"][x], np.nan))
    x += 1
    if x%5 == True:
        time.sleep(5)
        print(x - 100000, " done")
# Out:
# 30006  done
# 30011  done
# 30016  done
# 30021  done
# 30026  done
# 30031  done
# 30036  done
# 30041  done
# 30046  done
# 30051  done
# 30056  done
# 30061  done
# 30066  done
# 30071  done
# 30076  done
# 30081  done
# 30086  done
# 30091  done
# 30096  done
# 30101  done
# 30106  done
# 30111  done
# 30116  done
# 30121  done
# 30126  done
# 30131  done
# 30136  done
# 30141  done
# 30146  done
# 30151  done
# 30156  done
# 30161  done
# 30166  done
# 30171  done
# 30176  done
# 30181  done
# 30186  done
# 30191  done
# 30196  done
# 30201  done
# 30206  done
# 30211  done
# 30216  done
# 30221  done
# 30226  done
# 30231  done
# 30236  done
# 30241  done
# 30246  done
# 30251  done
# 30256  done
# 30261  done
# 30266  done
# 30271  done
# 30276  done
# 30281  done
# 30286  done
# 30291  done
# 30296  done
# 30301  done
# 30306  done
# 30311  done
# 30316  done
# 30321  done
# 30326  done
# 30331  done
# 30336  done
# 30341  done
# 30346  done
# 30351  done
# 30356  done
# ...

# %%
x = 140001
articles_4 = []
for i in df["link"].iloc[140001:150001]:
    article = Article(i)
    try:
        article.download()
        article.parse()
        articles_4.append((df["headline"][x], article.text.replace("\n", " ")))
    except:
        articles_4.append((df["headline"][x], np.nan))
    x += 1
    if x%5 == True:
        time.sleep(5)
        print(x - 100000, " done")
# Out:
# 40006  done
# 40011  done
# 40016  done
# 40021  done
# 40026  done
# 40031  done
# 40036  done
# 40041  done
# 40046  done
# 40051  done
# 40056  done
# 40061  done
# 40066  done
# 40071  done
# 40076  done
# 40081  done
# 40086  done
# 40091  done
# 40096  done
# 40101  done
# 40106  done
# 40111  done
# 40116  done
# 40121  done
# 40126  done
# 40131  done
# 40136  done
# 40141  done
# 40146  done
# 40151  done
# 40156  done
# 40161  done
# 40166  done
# 40171  done
# 40176  done
# 40181  done
# 40186  done
# 40191  done
# 40196  done
# 40201  done
# 40206  done
# 40211  done
# 40216  done
# 40221  done
# 40226  done
# 40231  done
# 40236  done
# 40241  done
# 40246  done
# 40251  done
# 40256  done
# 40261  done
# 40266  done
# 40271  done
# 40276  done
# 40281  done
# 40286  done
# 40291  done
# 40296  done
# 40301  done
# 40306  done
# 40311  done
# 40316  done
# 40321  done
# 40326  done
# 40331  done
# 40336  done
# 40341  done
# 40346  done
# 40351  done
# 40356  done
# ...

# %%
x = 150001
articles_5 = []
for i in df["link"].iloc[150001:160001]:
    article = Article(i)
    try:
        article.download()
        article.parse()
        articles_5.append((df["headline"][x], article.text.replace("\n", " ")))
    except:
        articles_5.append((df["headline"][x], np.nan))
    x += 1
    if x%5 == True:
        time.sleep(5)
        print(x - 100000, " done")
# Out:
# 50006  done
# 50011  done
# 50016  done
# 50021  done
# 50026  done
# 50031  done
# 50036  done
# 50041  done
# 50046  done
# 50051  done
# 50056  done
# 50061  done
# 50066  done
# 50071  done
# 50076  done
# 50081  done
# 50086  done
# 50091  done
# 50096  done
# 50101  done
# 50106  done
# 50111  done
# 50116  done
# 50121  done
# 50126  done
# 50131  done
# 50136  done
# 50141  done
# 50146  done
# 50151  done
# 50156  done
# 50161  done
# 50166  done
# 50171  done
# 50176  done
# 50181  done
# 50186  done
# 50191  done
# 50196  done
# 50201  done
# 50206  done
# 50211  done
# 50216  done
# 50221  done
# 50226  done
# 50231  done
# 50236  done
# 50241  done
# 50246  done
# 50251  done
# 50256  done
# 50261  done
# 50266  done
# 50271  done
# 50276  done
# 50281  done
# 50286  done
# 50291  done
# 50296  done
# 50301  done
# 50306  done
# 50311  done
# 50316  done
# 50321  done
# 50326  done
# 50331  done
# 50336  done
# 50341  done
# 50346  done
# 50351  done
# 50356  done
# ...

# %%
x = 160001
articles_6 = []
for i in df["link"].iloc[160001:170001]:
    article = Article(i)
    try:
        article.download()
        article.parse()
        articles_6.append((df["headline"][x], article.text.replace("\n", " ")))
    except:
        articles_6.append((df["headline"][x], np.nan))
    x += 1
    if x%5 == True:
        time.sleep(5)
        print(x - 100000, " done")
# Out:
# 60006  done
# 60011  done
# 60016  done
# 60021  done
# 60026  done
# 60031  done
# 60036  done
# 60041  done
# 60046  done
# 60051  done
# 60056  done
# 60061  done
# 60066  done
# 60071  done
# 60076  done
# 60081  done
# 60086  done
# 60091  done
# 60096  done
# 60101  done
# 60106  done
# 60111  done
# 60116  done
# 60121  done
# 60126  done
# 60131  done
# 60136  done
# 60141  done
# 60146  done
# 60151  done
# 60156  done
# 60161  done
# 60166  done
# 60171  done
# 60176  done
# 60181  done
# 60186  done
# 60191  done
# 60196  done
# 60201  done
# 60206  done
# 60211  done
# 60216  done
# 60221  done
# 60226  done
# 60231  done
# 60236  done
# 60241  done
# 60246  done
# 60251  done
# 60256  done
# 60261  done
# 60266  done
# 60271  done
# 60276  done
# 60281  done
# 60286  done
# 60291  done
# 60296  done
# 60301  done
# 60306  done
# 60311  done
# 60316  done
# 60321  done
# 60326  done
# 60331  done
# 60336  done
# 60341  done
# 60346  done
# 60351  done
# 60356  done
# ...

# %%
x = 170001
articles_7 = []
for i in df["link"].iloc[170001:180001]:
    article = Article(i)
    try:
        article.download()
        article.parse()
        articles_7.append((df["headline"][x], article.text.replace("\n", " ")))
    except:
        articles_7.append((df["headline"][x], np.nan))
    x += 1
    if x%5 == True:
        time.sleep(5)
        print(x - 100000, " done")
# Out:
# 70006  done
# 70011  done
# 70016  done
# 70021  done
# 70026  done
# 70031  done
# 70036  done
# 70041  done
# 70046  done
# 70051  done
# 70056  done
# 70061  done
# 70066  done
# 70071  done
# 70076  done
# 70081  done
# 70086  done
# 70091  done
# 70096  done
# 70101  done
# 70106  done
# 70111  done
# 70116  done
# 70121  done
# 70126  done
# 70131  done
# 70136  done
# 70141  done
# 70146  done
# 70151  done
# 70156  done
# 70161  done
# 70166  done
# 70171  done
# 70176  done
# 70181  done
# 70186  done
# 70191  done
# 70196  done
# 70201  done
# 70206  done
# 70211  done
# 70216  done
# 70221  done
# 70226  done
# 70231  done
# 70236  done
# 70241  done
# 70246  done
# 70251  done
# 70256  done
# 70261  done
# 70266  done
# 70271  done
# 70276  done
# 70281  done
# 70286  done
# 70291  done
# 70296  done
# 70301  done
# 70306  done
# 70311  done
# 70316  done
# 70321  done
# 70326  done
# 70331  done
# 70336  done
# 70341  done
# 70346  done
# 70351  done
# 70356  done
# ...

# %%
x = 180001
articles_8 = []
for i in df["link"].iloc[180001:190001]:
    article = Article(i)
    try:
        article.download()
        article.parse()
        articles_8.append((df["headline"][x], article.text.replace("\n", " ")))
    except:
        articles_8.append((df["headline"][x], np.nan))
    x += 1
    if x%5 == True:
        time.sleep(5)
        print(x - 100000, " done")
# Out:
# 80006  done
# 80011  done
# 80016  done
# 80021  done
# 80026  done
# 80031  done
# 80036  done
# 80041  done
# 80046  done
# 80051  done
# 80056  done
# 80061  done
# 80066  done
# 80071  done
# 80076  done
# 80081  done
# 80086  done
# 80091  done
# 80096  done
# 80101  done
# 80106  done
# 80111  done
# 80116  done
# 80121  done
# 80126  done
# 80131  done
# 80136  done
# 80141  done
# 80146  done
# 80151  done
# 80156  done
# 80161  done
# 80166  done
# 80171  done
# 80176  done
# 80181  done
# 80186  done
# 80191  done
# 80196  done
# 80201  done
# 80206  done
# 80211  done
# 80216  done
# 80221  done
# 80226  done
# 80231  done
# 80236  done
# 80241  done
# 80246  done
# 80251  done
# 80256  done
# 80261  done
# 80266  done
# 80271  done
# 80276  done
# 80281  done
# 80286  done
# 80291  done
# 80296  done
# 80301  done
# 80306  done
# 80311  done
# 80316  done
# 80321  done
# 80326  done
# 80331  done
# 80336  done
# 80341  done
# 80346  done
# 80351  done
# 80356  done
# ...

# %%
x = 190001
articles_9 = []
for i in df["link"].iloc[190001:200001]:
    article = Article(i)
    try:
        article.download()
        article.parse()
        articles_9.append((df["headline"][x], article.text.replace("\n", " ")))
    except:
        articles_9.append((df["headline"][x], np.nan))
    x += 1
    if x%5 == True:
        time.sleep(5)
        print(x - 100000, " done")
# Out:
# 90006  done
# 90011  done
# 90016  done
# 90021  done
# 90026  done
# 90031  done
# 90036  done
# 90041  done
# 90046  done
# 90051  done
# 90056  done
# 90061  done
# 90066  done
# 90071  done
# 90076  done
# 90081  done
# 90086  done
# 90091  done
# 90096  done
# 90101  done
# 90106  done
# 90111  done
# 90116  done
# 90121  done
# 90126  done
# 90131  done
# 90136  done
# 90141  done
# 90146  done
# 90151  done
# 90156  done
# 90161  done
# 90166  done
# 90171  done
# 90176  done
# 90181  done
# 90186  done
# 90191  done
# 90196  done
# 90201  done
# 90206  done
# 90211  done
# 90216  done
# 90221  done
# 90226  done
# 90231  done
# 90236  done
# 90241  done
# 90246  done
# 90251  done
# 90256  done
# 90261  done
# 90266  done
# 90271  done
# 90276  done
# 90281  done
# 90286  done
# 90291  done
# 90296  done
# 90301  done
# 90306  done
# 90311  done
# 90316  done
# 90321  done
# 90326  done
# 90331  done
# 90336  done
# 90341  done
# 90346  done
# 90351  done
# 90356  done
# ...

# %%
articles_final = articles + articles_1 + articles_2 + articles_3 + articles_4 + articles_5 + articles_6 + articles_7 + articles_8 + articles_9

# %%
headline = []
article = []

for i in range(len(articles_final)):
    headline.append(articles_final[i][0])
    article.append(articles_final[i][1])


df_2["headline"] = headline
df_2["full_text"] = article

# %%
df_updated = pd.concat([df, df_2], axis = 1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7628c42dac80> in <module>
# ----> 1 df_updated = pd.concat([df, df_2], axis = 1)
#
# NameError: name 'pd' is not defined

# %%
df_updated.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-7fdb86084439> in <module>
# ----> 1 df_updated.head()
#
# NameError: name 'df_updated' is not defined

# %%
article

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-00cf07b74dcd> in <module>
# ----> 1 df
#
# NameError: name 'df' is not defined
